# %% [markdown]
# <a href="https://colab.research.google.com/github/yongi-spec/study/blob/main/classification_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/yongi-spec/study.git
# Out:
# Cloning into 'study'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 21 (delta 6), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), 600.32 KiB | 2.37 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
